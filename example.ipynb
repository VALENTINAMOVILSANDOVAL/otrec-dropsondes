# %%
# Import the main functions from the otrec_dropsondes package
import otrec_dropsondes

# Optional: If you update the .py files, this auto-reloads the changes in Jupyter
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Generate all plots for just one specific case
otrec_dropsondes.generate_case_plots(
    case_id   = '0823',
    data_dir  = '/Users/valentinamovilsandoval/Documents/Projects/PV/data',
    output_dir= './plots'
)
# Out:
# === Generating plots for case 0823 (20190823/box2) ===
#   ✅  iisf.pdf
#   ✅  ppiplot.pdf
#   ✅  mflux.pdf
#   ✅  src.pdf
#   ✅  surf.pdf
#   ✅  sst_wind.pdf
#   ✅  vort.pdf
#   ✅  zlatplot.pdf
#   ✅  latplot.pdf
#   ✅  profs.pdf
#   ✅  sndplot.pdf
#   ✅  mfluxplot.pdf
#   → Saved to ./plots/0823/

# %%
# Automatically process all 22 registered cases
otrec_dropsondes.process_all_cases(
    data_dir  = '/Users/valentinamovilsandoval/Documents/Projects/PV/data',
    output_dir= './plots'
 )
# Out:
# === Generating plots for case 0807 (20190807/box2) ===
#   ✅  iisf.pdf
#   ✅  ppiplot.pdf
#   ✅  mflux.pdf
#   ✅  src.pdf
#   ✅  surf.pdf
#   ✅  sst_wind.pdf
#   ✅  vort.pdf
#   ✅  zlatplot.pdf
#   ✅  latplot.pdf
#   ✅  profs.pdf
#   ✅  sndplot.pdf
#   ✅  mfluxplot.pdf
#   → Saved to ./plots/0807/
#
# === Generating plots for case 0811 (20190811/box1) ===
#   ✅  iisf.pdf
# /Users/valentinamovilsandoval/Documents/Projects/PV/otrec-dropsondes/otrec_dropsondes/generate_case_plots.py:48: UserWarning: iisf: not defined for this case — skipping.
#   warnings.warn('iisf: not defined for this case — skipping.'); return
# /Users/valentinamovilsandoval/Documents/Projects/PV/otrec-dropsondes/otrec_dropsondes/generate_case_plots.py:77: UserWarning: mflux: not defined for this case — skipping.
#   warnings.warn('mflux: not defined for this case — skipping.'); return
# ...
